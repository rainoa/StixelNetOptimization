stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002561_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000226_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003421_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000056_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002671_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001126_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002966_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002826_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003261_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001206_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001006_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001736_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003426_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002931_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002061_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002766_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003631_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003721_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000221_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001426_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003166_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002851_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003981_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001471_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002116_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001421_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002996_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003656_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001001_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000004531_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000921_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003876_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000004501_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001061_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000441_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002911_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003881_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000111_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000004016_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003601_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000004276_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000004051_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002221_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002196_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002971_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000004476_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002251_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002226_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001491_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000066_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001771_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000004371_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003081_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002746_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003536_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003041_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003106_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000004551_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003666_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000004181_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001646_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002501_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002816_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000611_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003256_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000856_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000456_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003011_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000004636_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000151_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003116_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000061_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003051_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000001796_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000003146_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000002856_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0034_frame_0000000071_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0058_sync
# 2011_10_03_drive_0047_sync
# 2011_10_03_drive_0047_frame_0000000166_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000596_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000771_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000151_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000321_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000726_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000416_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000831_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000256_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000211_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000186_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000096_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000136_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000806_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000776_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000246_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000216_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000801_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000506_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000751_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000366_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000301_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000306_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000636_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000531_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000426_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000411_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000571_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000716_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000201_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000281_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000401_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000066_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000396_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000606_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000251_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000431_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000171_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000176_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000386_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000076_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000591_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000566_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000556_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000291_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000601_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000676_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000681_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000461_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000041_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000316_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000156_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000196_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000706_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000721_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000711_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000181_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000476_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000266_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000406_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000651_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000206_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000501_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000236_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000491_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000141_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000551_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000351_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000791_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# 2011_10_03_drive_0047_frame_0000000646_stixel_000
# img.shape[0]= 376
# s.shape[0]= 370
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f12b7b252cd8> in <module>()
# ----> 1 preprocess_data()
#
# /home/noa_raindel/NexarStixelnet/preprocess_func_save_stx.py in preprocess_data(dates, data_path, dir_path, output_dir, seedNum)
#      53             for frame in frames_shuff[:int(numFrames*0.7)]:
#      54                 labels_train_tmp = save_stixels_return_labels_from_frame(date, series, frame, data_path,
# ---> 55                                                                          output_dir = os.path.join(homedir, output_dir, 'train'))
#      56                 labels_train += labels_train_tmp
#      57
#
# /home/noa_raindel/NexarStixelnet/preprocess_func_save_stx.py in save_stixels_return_labels_from_frame(date, series, frame, data_path, output_dir)
#     159
#     160             # save the stixel image
# --> 161             scipy.misc.imsave(os.path.join(output_dir, imName + '.png'), s)
#     162
#     163             # calculate the label value
#
# /home/noa_raindel/.TF_cpu_new/lib/python3.5/site-packages/scipy/misc/pilutil.py in imsave(name, arr, format)
#     163
#     164     """
# --> 165     im = toimage(arr)
#     166     if format is None:
#     167         im.save(name)
#
# /home/noa_raindel/.TF_cpu_new/lib/python3.5/site-packages/scipy/misc/pilutil.py in toimage(arr, high, low, cmin, cmax, pal, mode, channel_axis)
#     286         raise ValueError("Channel axis dimension is not valid.")
#     287
# --> 288     bytedata = bytescale(data, high=high, low=low, cmin=cmin, cmax=cmax)
#     289     if ca == 2:
#     290         strdata = bytedata.tostring()
#
# /home/noa_raindel/.TF_cpu_new/lib/python3.5/site-packages/scipy/misc/pilutil.py in bytescale(data, cmin, cmax, high, low)
#      94
#      95     scale = float(high - low) / cscale
# ---> 96     bytedata = (data * 1.0 - cmin) * scale + 0.4999
#      97     bytedata[bytedata > high] = high
#      98     bytedata[bytedata < 0] = 0
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame.from_csv('/home/noa_raindel/datasets/stixels/train/labels_train_2011_09_26_drive_0027.csv')
len(df.index[df['Use_stixel'] == 1].tolist())
# Out:
# /home/noa_raindel/.TF_cpu_new/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.
# 231
